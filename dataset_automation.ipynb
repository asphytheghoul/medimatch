# %%
import pandas as pd
import os

# %%
df = pd.read_csv("A_Z_medicines_dataset_of_India.csv")
df.head()
# Out:
#    id                      name  price(₹)  Is_discontinued  \
# 0   1  Augmentin 625 Duo Tablet    223.42            False
# 1   2       Azithral 500 Tablet    132.36            False
# 2   3          Ascoril LS Syrup    118.00            False
# 3   4      Allegra 120mg Tablet    218.81            False
# 4   5            Avil 25 Tablet     10.96            False
#
#                       manufacturer_name       type         pack_size_label  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 15 tablets
#
#       short_composition1          short_composition2
# 0  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# ...

# %%
meds = """Betacap 10 Tablet
Brigrel Tablet
Bigomet SR 500 Tablet
Buspin 10 Tablet
Broncofil N Tablet
Bisoheart-AM 2.5 Tablet
Briv 50mg Tablet
Baga-NT Tablet
Benitowa 8 Tablet
Bladmir-S 50 Tablet ER
combiflam tablet
clavam 625 tablet
cyclopam tablet
cetrizine tablet
ceftum 500mg tablet
cefix 200 tablet
cyra-d capsule
cilacar 10 tablet
ciplox 500 tablet
crocin advance tablet
crocin pain relief tablet
cepodem 200 tablet
calpol 500mg tablet
concor cor 2.5 tablet
cefakind 500 tablet
cefakind-cv 500 tablet
calpol 650mg tablet
concor 5 tablet
candiforce 200 capsule
ciplox tz tablet
cidmus 50mg tablet
cepodem xp 325 tablet
cetzine tablet
calpol t tablet
claribid 500 tablet
cyra 20mg tablet
fluka 150 tablet
flexon mr tablet
febutaz 40 tablet
faronem 200 tablet
frisium 5 tablet
fludac capsule
famocid 40 tablet
gabapin nt tablet"""
names = meds.split("\n")
names
# Out:
# ['Betacap 10 Tablet',
#  'Brigrel Tablet',
#  'Bigomet SR 500 Tablet',
#  'Buspin 10 Tablet',
#  'Broncofil N Tablet',
#  'Bisoheart-AM 2.5 Tablet',
#  'Briv 50mg Tablet',
#  'Baga-NT Tablet',
#  'Benitowa 8 Tablet',
#  'Bladmir-S 50 Tablet ER',
#  'combiflam tablet',
#  'clavam 625 tablet',
#  'cyclopam tablet',
#  'cetrizine tablet',
#  'ceftum 500mg tablet',
#  'cefix 200 tablet',
#  'cyra-d capsule',
#  'cilacar 10 tablet',
#  'ciplox 500 tablet',
#  'crocin advance tablet',
#  'crocin pain relief tablet',
#  'cepodem 200 tablet',
#  'calpol 500mg tablet',
#  'concor cor 2.5 tablet',
#  'cefakind 500 tablet',
#  'cefakind-cv 500 tablet',
#  'calpol 650mg tablet',
#  'concor 5 tablet',
#  'candiforce 200 capsule',
#  'ciplox tz tablet',
#  'cidmus 50mg tablet',
#  'cepodem xp 325 tablet',
#  'cetzine tablet',
#  'calpol t tablet',
#  'claribid 500 tablet',
#  'cyra 20mg tablet',
#  'fluka 150 tablet',
#  'flexon mr tablet',
#  'febutaz 40 tablet',
#  'faronem 200 tablet',
# ...

# %%
len(names)
# Out:
# 44

# %%
new_df = pd.read_csv("medicine_NLP - Sheet1.csv")
new_df.head(7)
# Out:
#                                          IMAGE LINKS  OCR-TEXT  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 5  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 6  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
#
#                    NAME                                    CHEMICAL NAME
# 0      Montek LC tablet        Levocetirizine (5mg) , Montelukast (10mg)
# 1  Amoxyclav 625 Tablet  Amoxycillin  (500mg) ,  Clavulanic Acid (125mg)
# 2       Azee 500 tablet                             Azithromycin (500mg)
# 3     Aciloc 150 Tablet                               Ranitidine (150mg)
# 4        Arkamin tablet                               Clonidine (100mcg)
# ...

# %%
# new_df.drop(["CHEMICAL NAME"],axis=1,inplace=True)
new_df.drop(["short_composition1","short_composition2"],axis=1,inplace=True)

# %%
new_df.head()
# Out:
#                                          IMAGE LINKS  OCR-TEXT  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
#
#                    NAME
# 0      Montek LC tablet
# 1  Amoxyclav 625 Tablet
# 2       Azee 500 tablet
# 3     Aciloc 150 Tablet
# 4        Arkamin tablet

# %%
# new_df["short_composition2"]= new_df["NAME"]
# new_df.head()
# Out:
#                                          IMAGE LINKS  OCR-TEXT  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
#
#                    NAME    short_composition1    short_composition2
# 0      Montek LC tablet      Montek LC tablet      Montek LC tablet
# 1  Amoxyclav 625 Tablet  Amoxyclav 625 Tablet  Amoxyclav 625 Tablet
# 2       Azee 500 tablet       Azee 500 tablet       Azee 500 tablet
# 3     Aciloc 150 Tablet     Aciloc 150 Tablet     Aciloc 150 Tablet
# 4        Arkamin tablet        Arkamin tablet        Arkamin tablet

# %%
new_df.drop(["short_composition1","short_composition2"],axis=1,inplace=True)

# %%
new_df.head()
# Out:
#                                          IMAGE LINKS  OCR-TEXT  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
#
#                    NAME
# 0      Montek LC tablet
# 1  Amoxyclav 625 Tablet
# 2       Azee 500 tablet
# 3     Aciloc 150 Tablet
# 4        Arkamin tablet

# %%
new_df['short_composition1'] = pd.Series([], dtype=float)
new_df['short_composition2'] = pd.Series([], dtype=float)

# %%
new_df.drop(["col3"],axis=1,inplace=True)

# %%
new_df.head()
# Out:
#                                          IMAGE LINKS  OCR-TEXT  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
#
#                    NAME  short_composition1  short_composition2
# 0      Montek LC tablet                 NaN                 NaN
# 1  Amoxyclav 625 Tablet                 NaN                 NaN
# 2       Azee 500 tablet                 NaN                 NaN
# 3     Aciloc 150 Tablet                 NaN                 NaN
# 4        Arkamin tablet                 NaN                 NaN

# %%
B.drop(["short_composition1","short_composition2"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    id                      name  price(₹)  Is_discontinued  \
# 0   1  Augmentin 625 Duo Tablet    223.42            False
# 1   2       Azithral 500 Tablet    132.36            False
# 2   3          Ascoril LS Syrup    118.00            False
# 3   4      Allegra 120mg Tablet    218.81            False
# 4   5            Avil 25 Tablet     10.96            False
#
#                       manufacturer_name       type         pack_size_label  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 15 tablets
#
#       short_composition1          short_composition2
# 0  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# ...

# %%
A = df

# %%
for row in A['name']:
    row.lower()

# %%
A["name"] = A["name"].str.lower()

# %%
A.head()
# Out:
#    id                      name  price(₹)  Is_discontinued  \
# 0   1  augmentin 625 duo tablet    223.42            False
# 1   2       azithral 500 tablet    132.36            False
# 2   3          ascoril ls syrup    118.00            False
# 3   4      allegra 120mg tablet    218.81            False
# 4   5            avil 25 tablet     10.96            False
#
#                       manufacturer_name       type         pack_size_label  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 15 tablets
#
#       short_composition1          short_composition2
# 0  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# ...

# %%
df.head()
# Out:
#    id                      name  price(₹)  Is_discontinued  \
# 0   1  augmentin 625 duo tablet    223.42            False
# 1   2       azithral 500 tablet    132.36            False
# 2   3          ascoril ls syrup    118.00            False
# 3   4      allegra 120mg tablet    218.81            False
# 4   5            avil 25 tablet     10.96            False
#
#                       manufacturer_name       type         pack_size_label  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 15 tablets
#
#       short_composition1          short_composition2
# 0  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# ...

# %%
import pandas as pd

# Create DataFrame A
A = df

# Create DataFrame B
B = new_df

# List of items to search for in DataFrame A
list_of_items = [x for x in new_df["NAME"]][:len(new_df["NAME"])-2]
list_of_items
# print(list_of_items)
# print(list_of_items)
# Iterate over the list of items
for item in list_of_items:
    # item = item.lower
    # Extract the values from the desired columns in DataFrame A for each item
    col1_value = df.loc[new_df['NAME'] == item.lower(), 'short_composition1']
    col2_value = df.loc[new_df['NAME'] == item.lower(), 'short_composition2']
    # print(item)
    # l1 = [x for x in df["name"]==item.lower()]
    # print(l1.count(True))
    col1_value = list(col1_value)
    col2_value = list(col2_value)
    # print(col1_value[0])
    # print(col2_value[0])
    # Append the values to DataFrame B as a new row
    B = B.append({'short_composition1': col1_value[0], 'short_composition2': col2_value[0]}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# c:\Users\Asus\Documents\ml\RV-AI\dataset_automation.ipynb Cell 21 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Asus/Documents/ml/RV-AI/dataset_automation.ipynb#X40sZmlsZQ%3D%3D?line=11'>12</a> # print(list_of_items)
#      <a href='vscode-notebook-cell:/c%3A/Users/Asus/Documents/ml/RV-AI/dataset_automation.ipynb#X40sZmlsZQ%3D%3D?line=12'>13</a> # print(list_of_items)
#      <a href='vscode-notebook-cell:/c%3A/Users/Asus/Documents/ml/RV-AI/dataset_automation.ipynb#X40sZmlsZQ%3D%3D?line=13'>14</a> # Iterate over the list of items
#      <a href='vscode-notebook-cell:/c%3A/Users/Asus/Documents/ml/RV-AI/dataset_automation.ipynb#X40sZmlsZQ%3D%3D?line=14'>15</a> for item in list_of_items:
# ...

# %%
# how to extract values from particular column in pandas dataframe
# https://stackoverflow.com/questions/17071871/how-to-select-rows-from-a-dataframe-based-on-column-values

for item in list_of_items:
    # B = B.append({'short_composition1': col1_value[0], 'short_composition2': col2_value[0]}, ignore_index=True)
    values = df.loc[df['name'] == item.lower(), 'short_composition1']
    values = list(values)
    print(item,values)
# Out:
# Montek LC tablet ['Levocetirizine (5mg) ']
# Amoxyclav 625 Tablet ['Amoxycillin  (500mg) ']
# Azee 500 tablet ['Azithromycin (500mg)', 'Azithromycin (500mg)']
# Aciloc 150 Tablet ['Ranitidine (150mg)']
# Arkamin tablet ['Clonidine (100mcg)']
# Alex Cough Lozenges []
# Atarax 10mg Tablet ['Hydroxyzine (10mg)']
# AB-FLO-N tablet ['Acebrophylline (100mg) ']
# ACEMIZ Plus Tablet ['Aceclofenac (100mg) ']
# AZICIP 500 tablet ['Azithromycin (500mg)', 'Azithromycin (500mg)']
# Anafortan 25 mg/300 mg Tablet ['Camylofin (25mg) ']
# atorva tablet ['Atorvastatin (10mg)']
# amlokind 5 tablet ['Amlodipine (5mg)']
# Amaryl 1mg Tablet ['Glimepiride (1mg)', 'Glimepiride (1mg)', 'Glimepiride (1mg)']
# Acivir 400 DT Tablet ['\'"\\\'nan\\\'"\'']
# Amlong Tablet ['Amlodipine (5mg)', 'Amlodipine (5mg)']
# ...

# %%
B.head()
# Out:
#                                          IMAGE LINKS  OCR-TEXT  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
#
#                    NAME short_composition1 short_composition2
# 0      Montek LC tablet                NaN                NaN
# 1  Amoxyclav 625 Tablet                NaN                NaN
# 2       Azee 500 tablet                NaN                NaN
# 3     Aciloc 150 Tablet                NaN                NaN
# 4        Arkamin tablet                NaN                NaN

# %%
# import pandas as pd

# # df = pd.DataFrame({'name': ['A', 'B', 'C', 'D'], 
# #                    'short_composition1': [1, 2, 3, 4], 
# #                    'short_composition2': [5, 6, 7, 8]})

# result_df = pd.DataFrame(columns=['name', 'short_composition1', 'short_composition2'])

# for index, row in df.iterrows():
#     result_df = result_df.append({'name': row['name'], 
#                                   'short_composition1': row['short_composition1'], 
#                                   'short_composition2': row['short_composition2']}, ignore_index=True)

# %%
result_df.head()
# Out:
#                                          IMAGE LINKS  OCR-TEXT  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...       NaN
#
#                    NAME short_composition1 short_composition2
# 0      Montek LC tablet                NaN                NaN
# 1  Amoxyclav 625 Tablet                NaN                NaN
# 2       Azee 500 tablet                NaN                NaN
# 3     Aciloc 150 Tablet                NaN                NaN
# 4        Arkamin tablet                NaN                NaN
