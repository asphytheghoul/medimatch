# %%
import easyocr
import cv2
from PIL import Image
import numpy as np

# %%
image = cv2.imread("images/scaled_research.png")
# image.resize((300,150,3))
image.shape
# Out:
# (344, 842, 3)

# %%
# img = Image.open("images/ultra-d3.png")
# img = img.resize((300,150))
# img = np.array(img)
# type(img)
# Out:
# numpy.ndarray

# %%
reader = easyocr.Reader(["en"],gpu=True)

# %%
results = reader.readtext(image,detail=1,paragraph=False)
results
# Out:
# [([[326, 20], [350, 20], [350, 28], [326, 28]], 'Yinn', 0.00699069257825613),
#  ([[365, 17], [521, 17], [521, 33], [365, 33]],
#   '05in14cdrAtten:',
#   0.0014936028830149072),
#  ([[58, 20], [146, 20], [146, 44], [58, 44]], 'Dlxiron', 0.7952663673635524),
#  ([[189, 25], [243, 25], [243, 41], [189, 41]], '@Odw m', 0.3372898879569481),
#  ([[325, 29], [527, 29], [527, 45], [325, 45]],
#   'Tulio]Ujjan; [e [ienr:r r re',
#   0.0007193214187775904),
#  ([[60, 46], [122, 46], [122, 52], [60, 52]], 'Cuanml', 0.01232583405271428),
#  ([[326, 46], [390, 46], [390, 54], [326, 54]],
#   'MLLMaATI',
#   0.09127489734119235),
#  ([[58, 56], [128, 56], [128, 64], [58, 64]],
#   'Tu tneolc',
#   0.038219323831078365),
#  ([[131, 55], [283, 55], [283, 67], [131, 67]],
#   'DMTI (louOnD IWOit @iind',
#   0.014324725612986053),
#  ([[326, 56], [362, 56], [362, 64], [326, 64]],
#   'Wdneng',
#   0.006587100379976285),
#  ([[366, 56], [434, 56], [434, 64], [366, 64]],
#   'Jmuhn Nhn [i',
#   0.017059232294001796),
#  ([[435, 53], [515, 53], [515, 67], [435, 67]],
#   '1Ild [7tveI;',
#   0.011661111526519602),
#  ([[58, 66], [126, 66], [126, 74], [58, 74]],
#   'TwEvo | F',
#   0.12932386208778157),
#  ([[200, 66], [230, 66], [230, 74], [200, 74]], 'nj [IU', 0.05484909234569422),
#  ([[325, 67], [379, 67], [379, 79], [325, 79]],
#   'WJunbin',
#   0.10202108388147914),
#  ([[382, 68], [428, 68], [428, 76], [382, 76]], 'Lea_', 0.05135142430663109),
#  ([[454, 66], [512, 66], [512, 74], [454, 74]],
#   'LnnauN',
#   0.011091098884764164),
#  ([[522, 64], [584, 64], [584, 72], [522, 72]],
#   'Mud A]_',
#   0.011224358012709226),
#  ([[667, 47], [687, 47], [687, 91], [667, 91]], '8', 0.33859637316169255),
#  ([[58, 76], [128, 76], [128, 84], [58, 84]],
#   'Iddnion',
#   0.0005336500426911774),
#  ([[202, 76], [230, 76], [230, 84], [202, 84]], '10 NO', 0.1477858873272622),
#  ([[326, 80], [374, 80], [374, 88], [326, 88]],
#   '[JA"ID N',
#   0.039007937209982094),
#  ([[373, 77], [449, 77], [449, 91], [373, 91]],
#   'Ju M MUJC',
#   0.21782609975757072),
#  ([[56, 88], [118, 88], [118, 96], [56, 96]], 'DJmU;Lnn', 0.19494156139060093),
#  ([[132, 88], [186, 88], [186, 96], [132, 96]],
#   'UPYPOMJU',
#   0.027685960324781662),
#  ([[56, 100], [98, 100], [98, 108], [56, 108]],
#   '0"j4Doni',
#   0.019413955019159383),
#  ([[116, 100], [154, 100], [154, 106], [116, 106]],
#   'Hen',
#   0.0022356440918915024),
#  ([[157, 97], [239, 97], [239, 109], [157, 109]],
#   "Vf'n PihWi",
#   0.04212572887870027),
#  ([[325, 91], [393, 91], [393, 103], [325, 103]],
#   'Ucnuda Vf',
#   0.1183893041025768),
#  ([[733, 69], [753, 69], [753, 125], [733, 125]], '3', 0.4936170301252538),
#  ([[192, 118], [246, 118], [246, 126], [192, 126]],
#   'Maaa',
#   0.013459516689181328),
#  ([[276, 116], [302, 116], [302, 124], [276, 124]],
#   '40 1 `',
#   0.004959509989388026),
#  ([[325, 122], [409, 122], [409, 130], [325, 130]],
#   'llanatnum',
#   0.0027339877629238263),
#  ([[348, 102], [433, 102], [433, 122], [348, 122]],
#   'alonnph',
#   0.5010584581300302),
#  ([[585, 99], [599, 99], [599, 149], [585, 149]], '1', 0.32244562762775786),
#  ([[669, 89], [689, 89], [689, 127], [669, 127]], '0', 0.1485244287771117),
#  ([[188, 128], [222, 128], [222, 136], [188, 136]], 'at]', 0.0088791224129177),
#  ([[350, 134], [450, 134], [450, 142], [350, 142]],
#   'Womtnicaannn',
#   0.01069834743378898),
#  ([[561, 95], [573, 95], [573, 163], [561, 163]], '1', 0.5167017292352547),
#  ([[671, 123], [691, 123], [691, 147], [671, 147]], '3', 0.11939755314387313),
#  ([[327, 141], [493, 141], [493, 157], [327, 157]],
#   '22VUMIQ Doln] @D?; Wlnri;',
#   0.0075368769661759314),
#  ([[499, 141], [543, 141], [543, 155], [499, 155]],
#   'Jato:',
#   0.12648310201204255),
#  ([[55, 157], [181, 157], [181, 173], [55, 173]],
#   'Mk #ll:MnDp',
#   0.02227932326081418),
#  ([[327, 153], [449, 153], [449, 167], [327, 167]],
#   'DhonnoinroWwN;',
#   0.08857120582587757),
#  ([[670, 122], [718, 122], [718, 204], [670, 204]], '4', 0.07817184058609428),
#  ([[706, 41], [769, 41], [769, 289], [706, 289]], '1', 0.21853939301094272),
#  ([[53, 177], [565, 177], [565, 217], [53, 217]],
#   'Cinnarizine & Dimenhydrinate Mouth',
#   0.8522663267135019),
#  ([[202, 210], [304, 210], [304, 242], [202, 242]],
#   'Tablets',
#   0.6942719469201803),
#  ([[329, 219], [359, 219], [359, 231], [329, 231]],
#   'Qalu',
#   0.8412805199623108),
#  ([[377, 217], [427, 217], [427, 229], [377, 229]],
#   'WuDL, @Y',
#   0.08104594453626157),
#  ([[436, 218], [458, 218], [458, 226], [436, 226]],
#   'MaIL',
#   0.013255841098725796),
#  ([[461, 213], [551, 213], [551, 231], [461, 231]],
#   '1yAmlm D*c',
#   0.06559299028572714),
#  ([[50, 211], [201, 211], [201, 249], [50, 249]],
#   'Dissolving',
#   0.9893018300610896),
#  ([[329, 229], [399, 229], [399, 241], [329, 241]],
#   'Dp mIeam',
#   0.02329265669577083),
#  ([[330, 242], [354, 242], [354, 250], [330, 250]],
#   'Jn',
#   0.034951626805565975),
#  ([[354, 235], [531, 235], [531, 251], [354, 251]],
#   '6] Itbact0D] QU [4 InliibjOndvo',
#   0.006220215200500744),
#  ([[54, 244], [144, 244], [144, 270], [54, 270]],
#   'Diziron',
#   0.9609032508223464),
#  ([[151, 245], [171, 245], [171, 267], [151, 267]], 'D', 0.9821093463263288),
#  ([[187, 249], [227, 249], [227, 265], [187, 265]],
#   'J!mir',
#   0.028868742531070933),
#  ([[331, 249], [535, 249], [535, 265], [331, 265]],
#   '(yjn] Vean ba Indaun bee )absriu',
#   0.0039042295743517957),
#  ([[54, 272], [124, 272], [124, 280], [54, 280]],
#   'cnn utnu',
#   0.04648837934224308),
#  ([[332, 268], [406, 268], [406, 276], [332, 276]],
#   'AANAVam',
#   0.0001863410948771414),
#  ([[683, 247], [701, 247], [701, 291], [683, 291]], '2', 0.9491354576995015),
#  ([[53, 279], [285, 279], [285, 295], [53, 295]],
#   'C"nuntot: nimniz   C)vimla',
#   0.025575445234131744),
#  ([[54, 294], [108, 294], [108, 302], [54, 302]], 'BMO', 0.03700238303084826),
#  ([[53, 303], [147, 303], [147, 315], [53, 315]],
#   'Drenibsd: U',
#   0.02014347463990257),
#  ([[53, 312], [177, 312], [177, 327], [53, 327]],
#   '0i7{Drdcd?',
#   0.009330264090808837),
#  ([[126, 324], [178, 324], [178, 332], [126, 332]],
#   'Flien',
#   9.487003866820153e-05),
#  ([[686.728562357417, 46.018505209144124],
#    [706.3329504743451, 44.02790872887857],
#    [713.271437642583, 122.98149479085588],
#    [692.6670495256549, 124.97209127112143]],
#   'D',
#   0.05303283010605342),
#  ([[697.7549468559947, 204.01506953355712],
#    [717.3058823529411, 202.0235294117647],
#    [724.2450531440053, 288.98493046644285],
#    [703.6941176470589, 289.9764705882353]],
#   '1',
#   0.0809732543284305)]
